# %%
# 1-1-2021
# jupyter lab --notebook-dir 'E:/stockProject'

# %%
# import logging
import numpy as np
import pandas as pd
import yfinance as yf
import datetime
import time
import requests
import io

import matplotlib.pyplot as plt
import matplotlib as mpl
import plotly.express as px

# %%
start = datetime.datetime(2021,1,1)   # 1988, 2010, 2016, 2014
end = datetime.datetime(2021,7,15)

# %%
# url="https://pkgstore.datahub.io/core/nasdaq-listings/nasdaq-listed_csv/data/7665719fb51081ba0bd834fde71ce822/nasdaq-listed_csv.csv"
# # https://pkgstore.datahub.io/core/nasdaq-listings/nasdaq-listed_csv/data/7665719fb51081ba0bd834fde71ce822/nasdaq-listed_csv.csv
# s = requests.get(url).content
# nasdaq_companies = pd.read_csv(io.StringIO(s.decode('utf-8')))
# nasdaq_companies.head()

# %%
# # explore the data
# print('memory :', nasdaq_companies.memory_usage().sum()/(1024*1024) , ' MB')

# print('nan cells: ', nasdaq_companies.isnull().sum().sum())
# print('nan rows: ', nasdaq_companies.isnull().any(axis=1).sum())
# print('df size: ' , nasdaq_companies.shape)
# print('nan rows %: ', nasdaq_companies.isnull().any(axis=1).sum()*100/companies.shape[0])
# companies.tail()

# %%
#nasdaq_companies.nunique()

# %%
#nasdaq_companies.info()

# %%
#nasdaq_companies['Financial Status'].unique()

# %%
#nasdaq_companies['Round Lot Size'].unique()

# %%
#nasdaq_companies.describe()

# %%
#nasdaq_companies_5prcnt_smpl= nasdaq_companies.sample(frac=0.1, random_state=7)

# %%
#nasdaq_companies_5prcnt_smpl.head(30)

# %%
# Symbols = nasdaq_companies['Symbol'].tolist()
# print(len(Symbols))
# Symbols[0:10]

# %%
yf.download.__code__.co_varnames
# Out:
# ('tickers',
#  'start',
#  'end',
#  'actions',
#  'threads',
#  'group_by',
#  'auto_adjust',
#  'back_adjust',
#  'progress',
#  'period',
#  'show_errors',
#  'interval',
#  'prepost',
#  'proxy',
#  'rounding',
#  'kwargs',
#  'i',
#  'ticker',
#  'data')

# %%
import inspect
inspect.signature(yf.download)
# Out:
# <Signature (tickers, start=None, end=None, actions=False, threads=True, group_by='column', auto_adjust=False, back_adjust=False, progress=True, period='max', show_errors=True, interval='1d', prepost=False, proxy=None, rounding=False, **kwargs)>

# %%
# nasdaqList = ['AAVL', 'ABAX', 'ABCD', 'ABCO', 'ACFC', 'ACTA', 'AFAM', 'AFCB', \
# 'AFSI', 'AHGP', 'ALOG', 'ANCB', 'ANCI', 'ANCX', 'ARII', \
# 'AVHI', 'BBOX', 'BBRG', 'BDMS', 'BIND', 'BSF', 'BYBK', 'CA', \
# 'CALD', 'CALL', 'CAVM', 'CCIH', 'CHFN', 'CNXR', 'COBZ', 'CORI', \
# 'CPLA', 'CRTN', 'CRWN', 'CSBK', 'CU', 'CWAY', 'DARA', 'DWCH', \
# 'DXM', 'ECYT', 'EDGW', 'ELON', 'ESIO', 'ESRX', 'ESYS', 'EXAC', \
# 'FFKT', 'FFNM', 'FINL', 'FMI', 'GAI', 'GALE', 'GBNK', 'GNBC', \
# 'GNCMA', 'HAWK', 'HCOM', 'HDNG', 'HDP', 'INTX', 'IPAS', \
# 'IPCC', 'IPXL', 'JMBA', 'JTPY', 'JUNO', 'JXSB', 'KANG', 'KERX', \
# 'KLXI', 'KTEC', 'KTWO', 'KYTH', 'LAYN', 'LIME', 'LNCE', 'LPNT', \
# 'LVNTB', 'MATR', 'MBFIP', 'MIFI', 'MITL', 'MSCC', 'MSFG', 'MTGE', \
# 'MULT', 'MZOR', 'NAME', 'NEWS', 'NRCIB', 'OCLR', 'ORIG', \
# 'PARN', 'PBSK', 'PCBK', 'PERF', 'PERY', 'PETM', 'PRSS', 'REIS', \
# 'RELV', 'RLJE', 'RMGN', 'RSYS', 'RXDX', 'SALE', 'SCMP', 'SGI', \
# 'SGNL', 'SHLM', 'SHPG', 'SIBC', 'SNMX', 'SODA', 'SONC', 'SPIL', \
# 'STBZ', 'STRN', 'SWSH', 'SYNT', 'TSRO', 'UCBA', 'VIMC', 'VIP', \
# 'VISN', 'WSCI', 'XCRA', 'XPLR' ]     #  from that stupid datahub
# len(nasdaqList)

# %%
# you might need to install openpyxl and defusedxml
nasdaq100=pd.read_excel('../data/nasdaq100.xlsx')   # read_csv
nasdaq30=pd.read_excel('../data/nasdaq30.xlsx', sheet_name='nasdaq30')   # install openpyxl 
nasdaq100.head()
# Out:
#                    Company Symbol             GICS_sector  \
# 0      Activision Blizzard   ATVI  Communication Services
# 1               Adobe Inc.   ADBE  Information Technology
# 2   Advanced Micro Devices    AMD  Information Technology
# 3  Alexion Pharmaceuticals   ALXN             Health Care
# 4         Align Technology   ALGN             Health Care
#
#                   GICS_sub_sector
# 0  Interactive Home Entertainment
# 1            Application Software
# 2                  Semiconductors
# 3                 Pharmaceuticals
# 4            Health Care Supplies

# %%
nasdaq30.head()
# Out:
#   Symbol                        Company
# 0   MRVL  Marvell Technology Group Ltd.
# 1   DLTR              Dollar Tree, Inc.
# 2   PCAR                     PACCAR Inc
# 3    KDP          Keurig Dr Pepper Inc.
# 4   SIRI        Sirius XM Holdings Inc.

# %%
#Symbols=nasdaqList

Symbols=nasdaq100['Symbol']
#Symbols=nasdaq30['Symbol']
#Symbols=Symbols.append('^GSPC')
Symbols=list(Symbols)
Symbols.append('^GSPC')
Symbols.append('^IXIC')
Symbols[0:5]
# Out:
# ['ATVI', 'ADBE', 'AMD', 'ALXN', 'ALGN']

# %%
# you might need to:
# pip uninstall yfinance 
# pip install yfinance --upgrade --no-cache-dir

# %%
# np.empty(n_rows*num_dfs, dtype=dt, 
# meh, pd.DataFrame(columns=np.arange(n_cols), index=np.arange(num_dfs*n_rows))
# anyway, use concatination of all dfs in a list
# %timeit somecode/function

# %%
#################                               #####################                          #########################
# np.empty(n_rows*num_dfs, dtype=dt

# create empty dataframe
stock_final = pd.DataFrame()
stock = []
# iterate over each symbol

for i in Symbols:  
    stock_tick = yf.download(i,start=start, end=end, progress=False)   # 1d  1wk  1m
    # append the individual stock prices 
    if len(stock_tick) != 0:
        stock_tick['Name']=i
        if (i=='^GSPC'): stock_tick['Name']='S&P500' 
        if (i=='^IXIC'): stock_tick['Name']='Nasdaq' 
        stock.append(stock_tick)

stock_final = pd.concat(stock)
stock_final.head()
# Out:
#                  Open       High        Low      Close  Adj Close   Volume  \
# Date
# 2021-01-04  92.699997  92.910004  89.220001  89.900002  89.466812  7423100
# 2021-01-05  90.320000  90.750000  89.099998  90.690002  90.253006  4544100
# 2021-01-06  89.059998  89.900002  87.889999  88.000000  87.575966  7422100
# 2021-01-07  88.860001  90.750000  88.269997  89.669998  89.237915  6142200
# 2021-01-08  90.070000  91.370003  89.529999  91.300003  90.860069  4408800
#
#             Name
# Date
# 2021-01-04  ATVI
# 2021-01-05  ATVI
# 2021-01-06  ATVI
# 2021-01-07  ATVI
# 2021-01-08  ATVI

# %%
# def Diff(li1, li2):
#     return (list(list(set(li1)-set(li2)) + list(set(li2)-set(li1))))
 
# # Driver Code
# li1 = [10, 15, 20, 25, 30, 35, 40]
# li2 = [25, 40, 35]
# print(Diff(li1, li2))

# %%
stock_final['Name'].unique()
# Out:
# array(['ATVI', 'ADBE', 'AMD', 'ALXN', 'ALGN', 'GOOGL', 'GOOG', 'AMZN',
#        'AEP', 'AMGN', 'ADI', 'ANSS', 'AAPL', 'AMAT', 'ASML', 'TEAM',
#        'ADSK', 'ADP', 'BIDU', 'BIIB', 'BKNG', 'AVGO', 'CDNS', 'CDW',
#        'CERN', 'CHTR', 'CHKP', 'CTAS', 'CSCO', 'CTSH', 'CMCSA', 'CPRT',
#        'COST', 'CSX', 'DXCM', 'DOCU', 'DLTR', 'EBAY', 'EA', 'EXC', 'FB',
#        'FAST', 'FISV', 'FOXA', 'FOX', 'GILD', 'IDXX', 'ILMN', 'INCY',
#        'INTC', 'INTU', 'ISRG', 'JD', 'KDP', 'KLAC', 'KHC', 'LRCX', 'LULU',
#        'MAR', 'MRVL', 'MTCH', 'MXIM', 'MELI', 'MCHP', 'MU', 'MSFT',
#        'MRNA', 'MDLZ', 'MNST', 'NTES', 'NFLX', 'NVDA', 'NXPI', 'ORLY',
#        'OKTA', 'PCAR', 'PAYX', 'PYPL', 'PTON', 'PEP', 'PDD', 'QCOM',
#        'REGN', 'ROST', 'SGEN', 'SIRI', 'SWKS', 'SPLK', 'SBUX', 'SNPS',
#        'TMUS', 'TSLA', 'TXN', 'TCOM', 'VRSN', 'VRSK', 'VRTX', 'WBA',
#        'WDAY', 'XEL', 'XLNX', 'ZM', 'S&P500', 'Nasdaq'], dtype=object)

# %%
len(stock_final['Name'].unique())
# Out:
# 104

# %%
print('shape: ', stock_final.shape)
stock_final.head(20)
# Out:
# shape:  (13832, 7)
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2021-01-04  92.699997  92.910004  89.220001  89.900002  89.466812   7423100
# 2021-01-05  90.320000  90.750000  89.099998  90.690002  90.253006   4544100
# 2021-01-06  89.059998  89.900002  87.889999  88.000000  87.575966   7422100
# 2021-01-07  88.860001  90.750000  88.269997  89.669998  89.237915   6142200
# 2021-01-08  90.070000  91.370003  89.529999  91.300003  90.860069   4408800
# 2021-01-11  91.300003  91.849998  90.550003  90.910004  90.471947   6685900
# 2021-01-12  91.000000  91.190002  87.959999  89.250000  88.819946   5401100
# 2021-01-13  89.639999  90.339996  88.440002  89.769997  89.337433   4223700
# 2021-01-14  90.160004  91.239998  89.650002  89.989998  89.556374   5466000
# 2021-01-15  89.989998  90.750000  88.570000  90.690002  90.253006   8461400
# 2021-01-19  90.919998  93.370003  90.830002  93.150002  92.701149   5711900
# ...

# %%
#stock_final[stock_final.index=='2004-01-09 09:30:00-05:00']

# %%
print('nan cells: ', stock_final.isnull().sum().sum())
print('nan rows: ', stock_final.isnull().any(axis=1).sum())
print('df size: ' , stock_final.shape)
print('nan rows %: ', stock_final.isnull().any(axis=1).sum()*100/stock_final.shape[0])
# Out:
# nan cells:  0
# nan rows:  0
# df size:  (13832, 7)
# nan rows %:  0.0

# %%
proper = stock_final.groupby(['Date', 'Name'])['Close'].first().unstack()
# a=proper.iloc[1000:1010,:]
# a[['AAVL','ABAX','ABCD','ABCO','ACFC','AAVL', 'CU']]

# %%
filledNaProper=proper.interpolate(method='linear', axis=0).bfill()
filledNaProper.head()
# Out:
# Name              AAPL        ADBE         ADI         ADP        ADSK  \
# Date
# 2021-01-04  129.410004  485.339996  146.020004  168.960007  296.839996
# 2021-01-05  131.009995  485.690002  148.630005  168.490005  301.700012
# 2021-01-06  126.599998  466.309998  149.300003  167.899994  302.869995
# 2021-01-07  130.919998  477.739990  155.610001  168.850006  315.200012
# 2021-01-08  132.050003  485.100006  156.740005  171.050003  319.850006
#
# Name              AEP        ALGN        ALXN       AMAT        AMD  ...  \
# Date                                                                 ...
# 2021-01-04  81.540001  526.460022  156.809998  86.870003  92.300003  ...
# 2021-01-05  81.430000  543.650024  157.360001  89.599998  92.769997  ...
# 2021-01-06  82.080002  540.390015  157.759995  90.830002  90.330002  ...
# 2021-01-07  79.889999  558.359985  155.750000  94.559998  95.160004  ...
# 2021-01-08  79.180000  570.530029  157.350006  95.559998  94.580002  ...
#
# ...

# %%
filledNaProper.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 133 entries, 2021-01-04 to 2021-07-14
# Columns: 104 entries, AAPL to ZM
# dtypes: float64(104)
# memory usage: 109.1 KB

# %%
stat=filledNaProper.describe()
stat
# Out:
# Name         AAPL        ADBE         ADI         ADP        ADSK         AEP  \
# count  133.000000  133.000000  133.000000  133.000000  133.000000  133.000000
# mean   129.955940  499.192558  157.708121  185.360526  287.379699   83.536391
# std      6.501079   43.840483    6.752021   12.900509   13.869473    3.406349
# min    116.360001  421.200012  144.059998  161.029999  253.100006   74.849998
# 25%    125.349998  469.730011  151.910004  171.050003  277.149994   80.970001
# 50%    129.710007  490.700012  158.300003  189.440002  286.959991   84.699997
# 75%    134.139999  514.679993  163.490005  195.860001  297.570007   86.000000
# max    149.149994  608.830017  172.160004  204.500000  320.130005   90.139999
#
# Name         ALGN        ALXN        AMAT         AMD  ...        TSLA  \
# count  133.000000  133.000000  133.000000  133.000000  ...  133.000000
# mean   576.166920  164.786090  123.342857   83.966541  ...  698.887519
# ...

# %%
mpl.rcParams["figure.figsize"] = [15, 5]
hist=plt.hist(stat.loc['min'], bins=100)
plt.title('min of each symbol')
plt.grid(True)
plt.grid(b=True, which='minor', linestyle='--', alpha=0.6)
plt.minorticks_on()

# %%
mpl.rcParams["figure.figsize"] = [15, 3]
plt.boxplot(stat.loc['min'], vert =False)
plt.grid(True)
plt.grid(b=True, which='minor', linestyle='--', alpha=0.6)
plt.minorticks_on()

# %%
stat.loc['min'].describe()
# Out:
# count      104.000000
# mean       418.816763
# std       1320.927767
# min          5.770000
# 25%         84.105000
# 50%        132.259995
# 75%        289.754990
# max      12609.160156
# Name: min, dtype: float64

# %%
filledNaProperBnChange=filledNaProper.apply(lambda x: (x/filledNaProper.iloc[0]-1)*100, axis=1)
print(filledNaProperBnChange.shape)
filledNaProperBnChange.head()
# Out:
# (133, 104)
# Name            AAPL      ADBE       ADI       ADP      ADSK       AEP  \
# Date
# 2021-01-04  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2021-01-05  1.236373  0.072116  1.787427 -0.278173  1.637251 -0.134904
# 2021-01-06 -2.171397 -3.920962  2.246267 -0.627375  2.031397  0.662253
# 2021-01-07  1.166830 -1.565914  6.567591 -0.065105  6.185156 -2.023549
# 2021-01-08  2.040027 -0.049448  7.341461  1.236977  7.751654 -2.894286
#
# Name            ALGN      ALXN       AMAT       AMD  ...       TSLA       TXN  \
# Date                                                 ...
# 2021-01-04  0.000000  0.000000   0.000000  0.000000  ...   0.000000  0.000000
# 2021-01-05  3.265206  0.350745   3.142622  0.509202  ...   0.731733  0.733573
# 2021-01-06  2.645974  0.605827   4.558535 -2.134346  ...   3.591537  1.232894
# 2021-01-07  6.059333 -0.675976   8.852302  3.098592  ...  11.821527  3.526076
# ...

# %%
filledNaProperBnChange=filledNaProperBnChange[[c for c in filledNaProperBnChange if c not in ['Nasdaq', 'S&P500']] + ['Nasdaq', 'S&P500']]
filledNaProperBnChange.head()
# Out:
# Name            AAPL      ADBE       ADI       ADP      ADSK       AEP  \
# Date
# 2021-01-04  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2021-01-05  1.236373  0.072116  1.787427 -0.278173  1.637251 -0.134904
# 2021-01-06 -2.171397 -3.920962  2.246267 -0.627375  2.031397  0.662253
# 2021-01-07  1.166830 -1.565914  6.567591 -0.065105  6.185156 -2.023549
# 2021-01-08  2.040027 -0.049448  7.341461  1.236977  7.751654 -2.894286
#
# Name            ALGN      ALXN       AMAT       AMD  ...      VRSK      VRSN  \
# Date                                                 ...
# 2021-01-04  0.000000  0.000000   0.000000  0.000000  ...  0.000000  0.000000
# 2021-01-05  3.265206  0.350745   3.142622  0.509202  ... -0.448543 -3.314918
# 2021-01-06  2.645974  0.605827   4.558535 -2.134346  ... -1.389988 -6.587699
# 2021-01-07  6.059333 -0.675976   8.852302  3.098592  ... -0.941445 -6.358274
# 2021-01-08  8.371007  0.344371  10.003447  2.470204  ... -0.975952 -5.215844
#
# ...

# %%
inspect.signature(px.line)
# Out:
# <Signature (data_frame=None, x=None, y=None, line_group=None, color=None, line_dash=None, hover_name=None, hover_data=None, custom_data=None, text=None, facet_row=None, facet_col=None, facet_col_wrap=0, facet_row_spacing=None, facet_col_spacing=None, error_x=None, error_x_minus=None, error_y=None, error_y_minus=None, animation_frame=None, animation_group=None, category_orders=None, labels=None, orientation=None, color_discrete_sequence=None, color_discrete_map=None, line_dash_sequence=None, line_dash_map=None, log_x=False, log_y=False, range_x=None, range_y=None, line_shape=None, render_mode='auto', title=None, template=None, width=None, height=None)>

# %%
filledNaProperBnChange['S&P500']
# Out:
# Date
# 2021-01-04     0.000000
# 2021-01-05     0.708260
# 2021-01-06     1.283288
# 2021-01-07     2.787082
# 2021-01-08     3.351574
#                 ...
# 2021-07-08    16.758406
# 2021-07-09    18.075201
# 2021-07-12    18.482699
# 2021-07-13    18.066017
# 2021-07-14    18.203557
# Name: S&P500, Length: 133, dtype: float64

# %%
fig = px.line(filledNaProperBnChange, x=filledNaProperBnChange.index, y=filledNaProperBnChange.columns, color="Name", title="nasdaq monthly") # x="columnName"
fig.update_traces(mode="markers+lines", hovertemplate=None, marker_size=5)


for d in fig['data']:
    if d['name'] == 'S&P500':
        d['line']['dash']='dash'
        d['line']['color']='black'
        d['line']['width']=10
    elif d['name'] == 'Nasdaq':
        d['line']['dash']='dot'
        d['line']['color']='red'
        d['line']['width']=10
    else:
         #d['line']['dash']='dot'
        d['line']['width']=3

#fig.add_annotation(x='2018', y=2000,  text="Text annotation with arrow", showarrow=True, arrowhead=1)

fig.write_html("../data/nasdaq100since2014.html")
#fig.show()

# %%
###################################################################################################################

# %%
# Retrieving List of World Major Stock Indices from Yahoo! Finance
# df_list = pd.read_html("https://finance.yahoo.com/world-indices/")   didn't work, no table error
df_list=pd.read_html(requests.get("https://finance.yahoo.com/world-indices/").text)
majorStockIdx = df_list[0]

majorStockIdx[0:16]
# Out:
#        Symbol                       Name  Last Price  Change % Change  \
# 0       ^GSPC                    S&P 500     4258.49  -68.67   -1.59%
# 1        ^DJI                     Dow 30    33962.04 -725.81   -2.09%
# 2       ^IXIC                     Nasdaq    14274.98 -152.25   -1.06%
# 3        ^NYA        NYSE COMPOSITE (DJ)    16052.71 -311.95   -1.91%
# 4        ^XAX  NYSE AMEX COMPOSITE INDEX     2896.23  -84.09   -2.82%
# 5    ^BUK100P                Cboe UK 100      680.83  -16.61   -2.38%
# 6        ^RUT               Russell 2000     2130.68  -32.56   -1.51%
# 7        ^VIX      CBOE Volatility Index       22.47    4.02  +21.79%
# 8       ^FTSE                   FTSE 100     6844.39 -163.70   -2.34%
# 9      ^GDAXI      DAX PERFORMANCE-INDEX    15133.20 -407.11   -2.62%
# 10      ^FCHI                     CAC 40     6295.97 -164.11   -2.54%
# 11  ^STOXX50E             ESTX 50 PR.EUR     3928.53 -107.24   -2.66%
# ...

# %%
tickerData = yf.Ticker('^GSPC')
tickerDf1 = tickerData.history(period='1d', start='2020-1-1', end='2020-12-31')

# %%
stock_list = []
for s in majorStockIdx.Symbol: # iterate for every stock indices
    # Retrieve data from Yahoo! Finance
    tickerData = yf.Ticker(s)
    tickerDf1 = tickerData.history(period='1d', start='2020-1-1', end='2020-12-31')
    # Save historical data 
    tickerDf1['ticker'] = s # don't forget to specify the index
    stock_list.append(tickerDf1)
# Concatenate all data
msi = pd.concat(stock_list, axis = 0)
# Out:
# - ^IPSA: No data found for this date range, symbol may be delisted
# - ^CASE30: No data found for this date range, symbol may be delisted

# %%
region_idx= { 'US & Canada' : ['^GSPC', '^DJI', '^IXIC', '^RUT','^GSPTSE'],
  'Latin America' : ['^BVSP', '^MXX'], #, '^IPSA'],
  'East Asia' : ['^N225', '^HSI', '000001.SS', '399001.SZ', '^TWII', '^KS11'],
  'ASEAN & Oceania' : ['^STI', '^JKSE', '^KLSE','^AXJO',  '^NZ50'],
  'South & West Asia' : ['^BSESN', '^TA125.TA'],
  'Europe' : ['^FTSE', '^GDAXI', '^FCHI', '^STOXX50E','^N100', '^BFX']
}

# %%
type(region_idx)
# Out:
# dict

# %%
def getRegion(ticker):
    for k in region_idx.keys():
        if ticker in region_idx[k]:
            return k
msi['region']= msi.ticker.apply(lambda x: getRegion(x))

# %%
msi.head()
# Out:
#                    Open         High          Low        Close        Volume  \
# Date
# 2020-01-02  3244.669922  3258.139893  3235.530029  3257.850098  3.458250e+09
# 2020-01-03  3226.360107  3246.149902  3222.340088  3234.850098  3.461290e+09
# 2020-01-06  3217.550049  3246.840088  3214.639893  3246.280029  3.674070e+09
# 2020-01-07  3241.860107  3244.909912  3232.429932  3237.179932  3.420380e+09
# 2020-01-08  3238.590088  3267.070068  3236.669922  3253.050049  3.720890e+09
#
#             Dividends  Stock Splits ticker  Adj Close       region
# Date
# 2020-01-02        0.0           0.0  ^GSPC        NaN  US & Canada
# 2020-01-03        0.0           0.0  ^GSPC        NaN  US & Canada
# 2020-01-06        0.0           0.0  ^GSPC        NaN  US & Canada
# 2020-01-07        0.0           0.0  ^GSPC        NaN  US & Canada
# 2020-01-08        0.0           0.0  ^GSPC        NaN  US & Canada

# %%
msi=msi.reset_index()
msi.head()
# Out:
#         Date         Open         High          Low        Close  \
# 0 2020-01-02  3244.669922  3258.139893  3235.530029  3257.850098
# 1 2020-01-03  3226.360107  3246.149902  3222.340088  3234.850098
# 2 2020-01-06  3217.550049  3246.840088  3214.639893  3246.280029
# 3 2020-01-07  3241.860107  3244.909912  3232.429932  3237.179932
# 4 2020-01-08  3238.590088  3267.070068  3236.669922  3253.050049
#
#          Volume  Dividends  Stock Splits ticker  Adj Close       region
# 0  3.458250e+09        0.0           0.0  ^GSPC        NaN  US & Canada
# 1  3.461290e+09        0.0           0.0  ^GSPC        NaN  US & Canada
# 2  3.674070e+09        0.0           0.0  ^GSPC        NaN  US & Canada
# 3  3.420380e+09        0.0           0.0  ^GSPC        NaN  US & Canada
# 4  3.720890e+09        0.0           0.0  ^GSPC        NaN  US & Canada

# %%
# Get the data for 4 Jan 2010
begRef = msi.loc[msi.Date == '2020-01-06']


def retBegin(ticker, val):
    try: 
        start_val = begRef.loc[begRef.ticker == ticker, 'Close'].values[0]
        ans= (val/start_val - 1) * 100
        return ans
    except Exception as exc:
        return np.nan
        #print('key ', ticker, ' type ', type(exc).__name__, end='\t')
        
msi['chBegin'] = msi.apply(lambda x: retBegin(x.ticker, x.Close), axis = 1)
msi.head()
# Out:
#         Date         Open         High          Low        Close  \
# 0 2020-01-02  3244.669922  3258.139893  3235.530029  3257.850098
# 1 2020-01-03  3226.360107  3246.149902  3222.340088  3234.850098
# 2 2020-01-06  3217.550049  3246.840088  3214.639893  3246.280029
# 3 2020-01-07  3241.860107  3244.909912  3232.429932  3237.179932
# 4 2020-01-08  3238.590088  3267.070068  3236.669922  3253.050049
#
#          Volume  Dividends  Stock Splits ticker  Adj Close       region  \
# 0  3.458250e+09        0.0           0.0  ^GSPC        NaN  US & Canada
# 1  3.461290e+09        0.0           0.0  ^GSPC        NaN  US & Canada
# 2  3.674070e+09        0.0           0.0  ^GSPC        NaN  US & Canada
# 3  3.420380e+09        0.0           0.0  ^GSPC        NaN  US & Canada
# 4  3.720890e+09        0.0           0.0  ^GSPC        NaN  US & Canada
#
#     chBegin
# 0  0.356410
# 1 -0.352093
# 2  0.000000
# 3 -0.280324
# 4  0.208547

# %%
msi['chBegin'].unique()
# Out:
# array([ 0.35641005, -0.35209321,  0.        , ...,  2.83288683,
#         2.99123838,  4.34732872])

# %%
# Transform the data to be ticker column-wise
chBegin = msi.groupby(['Date', 'ticker'])['chBegin'].first().unstack()
chBegin = msi.groupby(['Date', 'ticker'])['Close'].first().unstack()
# Fill null values with the values on the row before
chBegin = chBegin.fillna(method='bfill')
chBegin.head()
# Out:
# ticker        000001.SS     399001.SZ     IMOEX.ME        ^AORD        ^AXJO  \
# Date
# 2020-01-02  3085.197998  10638.820312  3076.370117  6810.000000  6690.600098
# 2020-01-03  3083.785889  10656.410156  3076.370117  6855.200195  6733.500000
# 2020-01-06  3083.407959  10698.269531  3078.870117  6857.399902  6735.700195
# 2020-01-07  3104.802002  10829.049805  3110.060059  6943.600098  6826.399902
# 2020-01-08  3066.893066  10706.870117  3110.060059  6930.100098  6817.600098
#
# ticker             ^BFX        ^BSESN    ^BUK100P     ^BVSP          ^DJI  \
# Date
# 2020-01-02  4015.929932  41626.640625  760.349976  118573.0  28868.800781
# 2020-01-03  3994.610107  41464.609375  760.780029  117707.0  28634.880859
# 2020-01-06  3971.780029  40676.628906  756.409973  116878.0  28703.380859
# 2020-01-07  3984.729980  40869.468750  756.809998  116662.0  28583.679688
# 2020-01-08  3980.689941  40817.738281  756.599976  116247.0  28745.089844
#
# ...

# %%
print('nan cells: ', chBegin.isnull().sum().sum())
print('nan rows: ', chBegin.isnull().any(axis=1).sum())
print('df size: ' , chBegin.shape)
print('nan rows %: ', chBegin.isnull().any(axis=1).sum()*100/chBegin.shape[0])
chBegin.tail()
# Out:
# nan cells:  25
# nan rows:  1
# df size:  (261, 34)
# nan rows %:  0.3831417624521073
# ticker        000001.SS     399001.SZ     IMOEX.ME        ^AORD        ^AXJO  \
# Date
# 2020-12-25  3396.562988  14017.059570  3258.949951  6962.100098  6700.299805
# 2020-12-28  3397.284912  14044.099609  3258.949951  6962.100098  6700.299805
# 2020-12-29  3379.035889  13970.209961  3274.669922  6962.100098  6700.299805
# 2020-12-30  3414.452881  14201.570312  3289.020020  6942.899902  6682.399902
# 2020-12-31  3473.069092  14470.679688          NaN  6850.600098  6587.100098
#
# ticker             ^BFX        ^BSESN    ^BUK100P     ^BVSP          ^DJI  \
# Date
# 2020-12-25  3663.060059  47353.750000  658.099976  119051.0  30403.970703
# 2020-12-28  3663.060059  47353.750000  658.099976  119051.0  30403.970703
# 2020-12-29  3671.110107  47613.078125  658.099976  119475.0  30335.669922
# 2020-12-30  3663.060059  47746.218750  652.669983  119306.0  30409.560547
# ...

# %%
chBegin.dropna(inplace=True)

# %%
chBegin.index.names
# Out:
# FrozenList(['Date'])

# %%
chBegin.axes
# Out:
# [DatetimeIndex(['2020-01-02', '2020-01-03', '2020-01-06', '2020-01-07',
#                 '2020-01-08', '2020-01-09', '2020-01-10', '2020-01-13',
#                 '2020-01-14', '2020-01-15',
#                 ...
#                 '2020-12-17', '2020-12-18', '2020-12-21', '2020-12-22',
#                 '2020-12-23', '2020-12-24', '2020-12-25', '2020-12-28',
#                 '2020-12-29', '2020-12-30'],
#                dtype='datetime64[ns]', name='Date', length=260, freq=None),
#  Index(['000001.SS', '399001.SZ', 'IMOEX.ME', '^AORD', '^AXJO', '^BFX',
#         '^BSESN', '^BUK100P', '^BVSP', '^DJI', '^FCHI', '^FTSE', '^GDAXI',
#         '^GSPC', '^GSPTSE', '^HSI', '^IXIC', '^JKSE', '^JN0U.JO', '^KLSE',
#         '^KS11', '^MERV', '^MXX', '^N100', '^N225', '^NYA', '^NZ50', '^RUT',
#         '^STI', '^STOXX50E', '^TA125.TA', '^TWII', '^VIX', '^XAX'],
#        dtype='object', name='ticker')]

# %%
chBegin.axes[0]
# Out:
# DatetimeIndex(['2020-01-02', '2020-01-03', '2020-01-06', '2020-01-07',
#                '2020-01-08', '2020-01-09', '2020-01-10', '2020-01-13',
#                '2020-01-14', '2020-01-15',
#                ...
#                '2020-12-17', '2020-12-18', '2020-12-21', '2020-12-22',
#                '2020-12-23', '2020-12-24', '2020-12-25', '2020-12-28',
#                '2020-12-29', '2020-12-30'],
#               dtype='datetime64[ns]', name='Date', length=260, freq=None)

# %%
chBegin.axes[1]
# Out:
# Index(['000001.SS', '399001.SZ', 'IMOEX.ME', '^AORD', '^AXJO', '^BFX',
#        '^BSESN', '^BUK100P', '^BVSP', '^DJI', '^FCHI', '^FTSE', '^GDAXI',
#        '^GSPC', '^GSPTSE', '^HSI', '^IXIC', '^JKSE', '^JN0U.JO', '^KLSE',
#        '^KS11', '^MERV', '^MXX', '^N100', '^N225', '^NYA', '^NZ50', '^RUT',
#        '^STI', '^STOXX50E', '^TA125.TA', '^TWII', '^VIX', '^XAX'],
#       dtype='object', name='ticker')

# %%
ticker=list(chBegin.axes[1])
ticker[0:3]
# Out:
# ['000001.SS', '399001.SZ', 'IMOEX.ME']

# %%
region_idx
# Out:
# {'US & Canada': ['^GSPC', '^DJI', '^IXIC', '^RUT', '^GSPTSE'],
#  'Latin America': ['^BVSP', '^MXX'],
#  'East Asia': ['^N225', '^HSI', '000001.SS', '399001.SZ', '^TWII', '^KS11'],
#  'ASEAN & Oceania': ['^STI', '^JKSE', '^KLSE', '^AXJO', '^NZ50'],
#  'South & West Asia': ['^BSESN', '^TA125.TA'],
#  'Europe': ['^FTSE', '^GDAXI', '^FCHI', '^STOXX50E', '^N100', '^BFX']}

# %%
#dict(zip(df.A,df.B))

# x=zip(majorStockIdx['Symbol'], majorStockIdx['Name'])
# print(tuple(x))
ticker=dict(zip(majorStockIdx['Symbol'], majorStockIdx['Name']))

# %%
mpl.rcParams["figure.figsize"] = [25, 5]

# %%
fig, axes = plt.subplots(3,2, figsize=(12, 8),sharex=True)
pagoda = ["#965757", "#D67469", "#4E5A44", "#A1B482", '#EFE482', "#99BFCF"] # for coloring
for i, k in enumerate(region_idx.keys()):
# Iterate for each region
    ax = axes[int(i/2), int(i%2)]
    for j,t in enumerate(region_idx[k]):
        # Iterate and plot for each stock index in this region
        ax.plot(chBegin.index, chBegin[t], marker='', linewidth=1, color = pagoda[j])
        ax.legend([ticker[t] for t in region_idx[k]], loc='upper left', fontsize=7)
        ax.set_title(k, fontweight='bold')
fig.text(0.5,0, "Year", ha="center", va="center", fontweight ="bold")
fig.text(0,0.5, "Price Change/Return (%)", ha="center", va="center", rotation=90, fontweight ="bold")
fig.suptitle("Price Change/Return for Major Stock Indices based on 2010", fontweight ="bold",y=1.05, fontsize=14)
fig.tight_layout()

# %%
###################################################################

# %%
import stocker as stck
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-127-349750b63034> in <module>
# ----> 1 import stocker as stck
#
# ModuleNotFoundError: No module named 'stocker'

# %%
stck.predict.tomorrow('AAPL')

# %%
amazon = stck.Stocker('AMZN')

# %%
amazon.plot_stock()

# %%
# predict days into the future
model, model_data = amazon.create_prophet_model(days=90)   # by Facebook for additive modeling

# %%
amazon.evaluate_prediction()

# %%
amazon.changepoint_prior_analysis(changepoint_priors=[0.001, 0.05, 0.1, 0.2])

# %%
amazon.changepoint_prior_analysis(changepoint_priors=[0.001, 0.05, 0.1, 0.15, 0.2, 0.25,0.4, 0.5, 0.6, 0.7])

# %%
amazon.changepoint_prior_validation(start_date='2016-01-04', end_date='2017-01-03', changepoint_priors=[0.001, 0.05, 0.1, 0.15, 0.2, 0.25,0.4, 0.5, 0.6, 0.7])

# %%
amazon.changepoint_prior_scale = 0.5

# %%
amazon.evaluate_prediction()

# %%
amazon.predict_future(days=3)
